# %% [markdown]
# # THE SPARKS FOUNDATION¶
#
# # TASK 2:- Prediction Using Decision Tree
#
# # NAME:- Gautam Malik

# %% [markdown]
# ## Importing Modules

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Importing Dataset

# %%
data=pd.read_csv('iris.csv')
data.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## Checking for Null Values

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.Species.value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
data.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
dic={'Iris-setosa':0,    'Iris-versicolor':1,    'Iris-virginica':2}
data.Species = data.Species.map(dic)

# %%
data.head(2)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0

# %%
X=data.drop(['Id','Species'],axis=1)
Y=data['Species']

# %% [markdown]
# ## HyperParameter Tuning

# %%
param = {"max_depth": [3, None], 
              "max_features": [1,2,3,4,5,6,7,8,9], 
              "min_samples_leaf": [1,2,3,4,5,6,7,8,9], 
              "criterion": ["gini", "entropy"]} 
m=DecisionTreeClassifier()
mod_cv=GridSearchCV(m,param_grid=param,cv=10,scoring='accuracy')
mod_cv.fit(X,Y)
# Out:
# c:\users\gautam\python\lib\site-packages\sklearn\model_selection\_validation.py:548: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "c:\users\gautam\python\lib\site-packages\sklearn\model_selection\_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\users\gautam\python\lib\site-packages\sklearn\tree\_classes.py", line 890, in fit
#     super().fit(
#   File "c:\users\gautam\python\lib\site-packages\sklearn\tree\_classes.py", line 279, in fit
#     raise ValueError("max_features must be in (0, n_features]")
# ValueError: max_features must be in (0, n_features]
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ...

# %%
mod_cv.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, max_features=3,
#                        min_samples_leaf=4)

# %%
mod_cv.best_score_
# Out:
# 0.9666666666666668

# %% [markdown]
# ## Creating Model

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=3)

# %%
model=DecisionTreeClassifier(criterion='entropy', max_depth=3, max_features=3,
                       min_samples_leaf=4)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, max_features=3,
#                        min_samples_leaf=4)

# %% [markdown]
# # Vizulizing Decision Tree

# %%
from sklearn import tree

# %%
plt.figure(figsize=(13,10))
tree.plot_tree(model,feature_names=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],
              class_names=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'],
              filled=True)
# Out:
# [Text(272.025, 475.65000000000003, 'PetalWidthCm <= 0.8\nentropy = 1.585\nsamples = 120\nvalue = [40, 40, 40]\nclass = Iris-setosa'),
#  Text(181.35, 339.75, 'entropy = 0.0\nsamples = 40\nvalue = [40, 0, 0]\nclass = Iris-setosa'),
#  Text(362.7, 339.75, 'PetalLengthCm <= 4.75\nentropy = 1.0\nsamples = 80\nvalue = [0, 40, 40]\nclass = Iris-versicolor'),
#  Text(181.35, 203.85000000000002, 'SepalLengthCm <= 5.15\nentropy = 0.179\nsamples = 37\nvalue = [0, 36, 1]\nclass = Iris-versicolor'),
#  Text(90.675, 67.94999999999999, 'entropy = 0.811\nsamples = 4\nvalue = [0, 3, 1]\nclass = Iris-versicolor'),
#  Text(272.025, 67.94999999999999, 'entropy = 0.0\nsamples = 33\nvalue = [0, 33, 0]\nclass = Iris-versicolor'),
#  Text(544.05, 203.85000000000002, 'PetalWidthCm <= 1.75\nentropy = 0.446\nsamples = 43\nvalue = [0, 4, 39]\nclass = Iris-virginica'),
#  Text(453.375, 67.94999999999999, 'entropy = 1.0\nsamples = 6\nvalue = [0, 3, 3]\nclass = Iris-versicolor'),
# ...

# %% [markdown]
# ## Making Predictions

# %%
pred=model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
print('Confusion Matrix :\n \n',confusion_matrix(y_test,pred))
# Out:
# Confusion Matrix :
#
#  [[10  0  0]
#  [ 0 10  0]
#  [ 0  1  9]]

# %%
print('Accuracy Score : ',accuracy_score(y_test,pred))
# Out:
# Accuracy Score :  0.9666666666666667
